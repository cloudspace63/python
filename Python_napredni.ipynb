# %% [markdown]
# <a href="https://colab.research.google.com/github/cloudspace63/python/blob/main/Python_napredni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
points = pd.Series([(1,3), (2,4), (6,4), (5,7)])
print(points.index)
RangeIndex(start=0, stop=4, step=1)
# Out:
# RangeIndex(start=0, stop=4, step=1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-529c4507224e> in <cell line: 0>()
#       1 points = pd.Series([(1,3), (2,4), (6,4), (5,7)])
#       2 print(points.index)
# ----> 3 RangeIndex(start=0, stop=4, step=1)
#
# NameError: name 'RangeIndex' is not defined

# %%
points=pd.Series([(1,3), (2,4), (6,4), (5,7)], index=["a", "b","c", "d"] )
print(points)
print(points.index)
# Out:
# a    (1, 3)
# b    (2, 4)
# c    (6, 4)
# d    (5, 7)
# dtype: object
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %% [markdown]
# SERIES KAO DICTIONARY:

# %%
points=pd.Series({'A':(1,3), 'B': (2,4), 'C':(6,4), 'D': (5,7)})
print(points)
print(points.index)
# Out:
# A    (1, 3)
# B    (2, 4)
# C    (6, 4)
# D    (5, 7)
# dtype: object
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %% [markdown]
# REINDEKSIRANJE: (nece izmeniti strukturu!)

# %%
points.reindex(index=['B','D','A','C'])
# Out:
# B    (2, 4)
# D    (5, 7)
# A    (1, 3)
# C    (6, 4)
# dtype: object

# %%
points
# Out:
# A    (1, 3)
# B    (2, 4)
# C    (6, 4)
# D    (5, 7)
# dtype: object

# %% [markdown]
# PRISTUPANJE POJEDINACNIM ELEMENTIMA:

# %%
points.C
# Out:
# (6, 4)

# %%
print(points['C'])
# Out:
# (6, 4)

# %%
print(points [['B', 'C']])
# Out:
# B    (2, 4)
# C    (6, 4)
# dtype: object

# %%
print(points[::2])
# Out:
# A    (1, 3)
# C    (6, 4)
# dtype: object

# %% [markdown]
# DATAFRAME objekti - 2D objekti

# %%
data=pd.DataFrame({
'name' : ['A', 'B', 'C', 'D'],
'x_value' : [1,2,6,5],
'y_value' : [3,4,4,7]
}
)

# %%
data
# Out:
#   name  x_value  y_value
# 0    A        1        3
# 1    B        2        4
# 2    C        6        4
# 3    D        5        7

# %%
print(data)
# Out:
#   name  x_value  y_value
# 0    A        1        3
# 1    B        2        4
# 2    C        6        4
# 3    D        5        7

# %% [markdown]
# KREIRANJE DATAFRAME-A NAVODJENJEM VRSTA:

# %%
data=pd.DataFrame(
    [['A', 1,3], ['B',2,4], ['C', 6,4], ['D', 5,7]], columns=['name', 'x_val', 'y_val']
)

# %%
data
# Out:
#   name  x_val  y_val
# 0    A      1      3
# 1    B      2      4
# 2    C      6      4
# 3    D      5      7

# %%
print('vrednosti:\n', data.values)
# Out:
# vrednosti:
#  [['A' 1 3]
#  ['B' 2 4]
#  ['C' 6 4]
#  ['D' 5 7]]

# %%
print('indeksi:\n', data.index)
# Out:
# indeksi:
#  RangeIndex(start=0, stop=4, step=1)

# %%
data.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8197be2c560b> in <cell line: 0>()
# ----> 1 data.values
#
# NameError: name 'data' is not defined

# %%
data.columns
# Out:
# Index(['name', 'x_val', 'y_val'], dtype='object')

# %%
data.set_index('name')
#nije trajna promena
# Out:
#       x_val  y_val
# name
# A         1      3
# B         2      4
# C         6      4
# D         5      7

# %%
data.set_index('name', inplace=True)
#ovako je trajno
#data=data.set_index('name')  ili ovako

# %%
data
# Out:
#       x_val  y_val
# name
# A         1      3
# B         2      4
# C         6      4
# D         5      7

# %% [markdown]
# EKSPLICITNA POSTAVKA INDEKSA

# %%
data=pd.DataFrame (
    [[1,3], [2,4], [6,4], [5,7]], columns=['x_val', 'y_val'], index=['A','B','C','D']
)

# %%
data
# Out:
#    x_val  y_val
# A      1      3
# B      2      4
# C      6      4
# D      5      7

# %% [markdown]
# OBJECT INDEXER LOC, ILOC

# %%
print(type(data.loc))
# Out:
# <class 'pandas.core.indexing._LocIndexer'>

# %%
print(data.loc['A','x_val'])
# Out:
# 1

# %%
print(data.iloc[0,0])
# Out:
# 1

# %%
data['x_val']
# Out:
# A    1
# B    2
# C    6
# D    5
# Name: x_val, dtype: int64

# %%
data['y_val']['A']
#ne moze da se pristupi 1 elementu bez iloca, loca
# Out:
# np.int64(3)

# %%
print(data.x_val)
# Out:
# A    1
# B    2
# C    6
# D    5
# Name: x_val, dtype: int64

# %%
print(data['x_val'])
# Out:
# A    1
# B    2
# C    6
# D    5
# Name: x_val, dtype: int64

# %%
print(data.iloc[:,1])
# Out:
# A    3
# B    4
# C    4
# D    7
# Name: y_val, dtype: int64

# %%
print(data.loc[:,'y_val'])
# Out:
# A    3
# B    4
# C    4
# D    7
# Name: y_val, dtype: int64

# %%
print(data.iloc[0,:])
# Out:
# x_val    1
# y_val    3
# Name: A, dtype: int64

# %%
print(data.iloc[0])
# Out:
# x_val    1
# y_val    3
# Name: A, dtype: int64

# %%
print(data.loc["A",:])
# Out:
# x_val    1
# y_val    3
# Name: A, dtype: int64

# %%
print(data.loc[:,'y_val'])

# %%
data.head()
# Out:
#    x_val  y_val
# A      1      3
# B      2      4
# C      6      4
# D      5      7

# %%
data.head(2)
# Out:
#    x_val  y_val
# A      1      3
# B      2      4

# %%
data[['x_val', 'y_val']]
#spisak za izadvajanje
# Out:
#    x_val  y_val
# A      1      3
# B      2      4
# C      6      4
# D      5      7

# %%
data.iloc[::2]
#izdvajanje vrsta
# Out:
#    x_val  y_val
# A      1      3
# C      6      4

# %%
data[data.x_val %2==0]
#izdvajanje parnih vrsta
# Out:
#    x_val  y_val
# B      2      4
# C      6      4

# %%
data.x_val %2==0
#ovime dobijemo novi objekat
# Out:
# A    False
# B     True
# C     True
# D    False
# Name: x_val, dtype: bool

# %%
data
# Out:
#    x_val  y_val
# A      1      3
# B      2      4
# C      6      4
# D      5      7

# %%
data.x_val
# Out:
# A    1
# B    2
# C    6
# D    5
# Name: x_val, dtype: int64

# %% [markdown]
# IZDVAJANJE PO OSAMA

# %%
#axis=0 po vrstama (podrazumevana osa)

# %%
#reindex po osi 0

# %%
data.reindex(['B','C','D','A'], axis=0)
#ovo je kao sort u Excelu
#privremeno menja
#ako hocu moj DF da menjam, idem data=data.reindex...
# Out:
#    x_val  y_val
# B      2      4
# C      6      4
# D      5      7
# A      1      3

# %%
data.reindex(['y_val', 'x_val'], axis=1)
# Out:
#    y_val  x_val
# A      3      1
# B      4      2
# C      4      6
# D      7      5

# %% [markdown]
# SORTIRANJE DF PO INDEXU REDOVA

# %%
data.sort_index()
# Out:
#    x_val  y_val
# A      1      3
# B      2      4
# C      6      4
# D      5      7

# %%
data.sort_index(ascending=False)
#inplace=True menja DF
# Out:
#    x_val  y_val
# D      5      7
# C      6      4
# B      2      4
# A      1      3

# %%
data
# Out:
#    x_val  y_val
# A      1      3
# B      2      4
# C      6      4
# D      5      7

# %%
data.sort_values(by='x_val')
# Out:
#    x_val  y_val
# A      1      3
# B      2      4
# D      5      7
# C      6      4

# %%
data.T
# Out:
#        A  B  C  D
# x_val  1  2  6  5
# y_val  3  4  4  7

# %% [markdown]
# UBACIVANJE KOLONE

# %%
data['color']=['blue', 'red', 'blue', 'blue']

# %%
data
# Out:
#    x_val  y_val color
# A      1      3  blue
# B      2      4   red
# C      6      4  blue
# D      5      7  blue

# %% [markdown]
# DODAVANJE REDA

# %%
data
# Out:
#    x_val  y_val color
# A      1      3  blue
# B      2      4   red
# C      6      4  blue
# D      5      7  blue

# %%
data.loc['E'] =[2,7,'green']

# %%
data
# Out:
#    x_val  y_val  color
# A      1      3   blue
# B      2      4    red
# C      6      4   blue
# D      5      7   blue
# E      2      7  green

# %% [markdown]
# SPAJANJE

# %%
data1 = data

# %%
df1=data[['x_val', 'y_val']]

# %%
df1
# Out:
#    x_val  y_val
# A      1      3
# B      2      4
# C      6      4
# D      5      7
# E      2      7

# %%
df2=pd.concat([data,df1], axis=1)

# %%
df2
# Out:
#    x_val  y_val  color  x_val  y_val
# A      1      3   blue      1      3
# B      2      4    red      2      4
# C      6      4   blue      6      4
# D      5      7   blue      5      7
# E      2      7  green      2      7

# %%
df3=data.iloc[-1:]

# %%
df3
# Out:
#    x_val  y_val  color
# E      2      7  green

# %%
df4=pd.concat([data,df1], axis=0)

# %%
df4
# Out:
#    x_val  y_val  color
# A      1      3   blue
# B      2      4    red
# C      6      4   blue
# D      5      7   blue
# E      2      7  green
# A      1      3    NaN
# B      2      4    NaN
# C      6      4    NaN
# D      5      7    NaN
# E      2      7    NaN

# %% [markdown]
# SPAJANJE DF-OVA SA NESLAGANJEM U INDEXIMA (razlicit broj kolona ili vrsta)

# %%
df1=data.iloc[:2, :3]

# %%
df1
# Out:
#    x_val  y_val color
# A      1      3  blue
# B      2      4   red

# %%
df2=data[['color'][:2]]

# %%
df2
# Out:
#    color
# A   blue
# B    red
# C   blue
# D   blue
# E  green

# %%
pd.concat([df1,df2], axis=1)
# Out:
#    x_val  y_val color  color
# A    1.0    3.0  blue   blue
# B    2.0    4.0   red    red
# C    NaN    NaN   NaN   blue
# D    NaN    NaN   NaN   blue
# E    NaN    NaN   NaN  green

# %%
df1
# Out:
#    x_val  y_val color
# A      1      3  blue
# B      2      4   red

# %%
df2
# Out:
#    color
# A   blue
# B    red
# C   blue
# D   blue
# E  green

# %%
df1.join(data)

# %%
data
# Out:
#    x_val  y_val  color
# A      1      3   blue
# B      2      4    red
# C      6      4   blue
# D      5      7   blue
# E      2      7  green

# %%
df2=data.iloc[:4, :2]

# %%
df2
# Out:
#    x_val  y_val
# A      1      3
# B      2      4
# C      6      4
# D      5      7

# %%
df1
# Out:
#    x_val  y_val color
# A      1      3  blue
# B      2      4   red

# %%
df3=df1.iloc[:,:2]

# %%
df3
# Out:
#    x_val  y_val
# A      1      3
# B      2      4

# %%
df1.merge(df3)
#Ovde mogu da se preklapaju kolone
# Out:
#    x_val  y_val color
# 0      1      3  blue
# 1      2      4   red

# %% [markdown]
# NEDOSTAJUCE VREDNOSTI

# %%
data
# Out:
#   name  x_val  y_val
# 0    A      1      3
# 1    B      2      4
# 2    C      6      4
# 3    D      5      7

# %%
data=data.iloc[:4,:3]

# %%
data=data.reindex(['x_val', 'y_val','color', 'nista'], axis=1)

# %%
data
# Out:
#    x_val  y_val color  nista
# A      1      3  blue    NaN
# B      2      4   red    NaN
# C      6      4  blue    NaN
# D      5      7  blue    NaN

# %%
data1=pd.DataFrame([[np.nan, np.nan, np.nan]], columns=['x_val', 'y_val', 'color'], index=['F'])

# %%
data1
#novi DataFrame
# Out:
#    x_val  y_val  color
# F    NaN    NaN    NaN

# %%
data=pd.concat([data,data1], axis=0)

# %%
data
# Out:
#    x_val  y_val color  nista
# A    1.0    3.0  blue    NaN
# B    2.0    4.0   red    NaN
# C    6.0    4.0  blue    NaN
# D    5.0    7.0  blue    NaN
# F    NaN    NaN   NaN    NaN

# %% [markdown]
# PROVERA DA LI IMA NEPOSTOJECE VREDNOSTI:

# %%
pd.isna(data)
# Out:
#    x_val  y_val  color  nista
# A  False  False  False   True
# B  False  False  False   True
# C  False  False  False   True
# D  False  False  False   True
# F   True   True   True   True

# %% [markdown]
# DA POPUNIMO NAN VREDNOSTI

# %%
data.fillna({'x_val':0, 'y_val':0, 'color':"black",'nista':0})
# Out:
#    x_val  y_val  color  nista
# A    1.0    3.0   blue    0.0
# B    2.0    4.0    red    0.0
# C    6.0    4.0   blue    0.0
# D    5.0    7.0   blue    0.0
# F    0.0    0.0  black    0.0

# %% [markdown]
# ** DROP **

# %%
data.dropna(how='all')
#podrazumeva se axis=0
# Out:
#    x_val  y_val color  nista
# A    1.0    3.0  blue    NaN
# B    2.0    4.0   red    NaN
# C    6.0    4.0  blue    NaN
# D    5.0    7.0  blue    NaN

# %%
data.dropna(how='all', axis=1)
# Out:
#    x_val  y_val color
# A    1.0    3.0  blue
# B    2.0    4.0   red
# C    6.0    4.0  blue
# D    5.0    7.0  blue
# F    NaN    NaN   NaN

# %%
data.dropna(how='any', axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [A, B, C, D, F]

# %%
pd.isna(data)
# Out:
#    x_val  y_val  color  nista
# A  False  False  False   True
# B  False  False  False   True
# C  False  False  False   True
# D  False  False  False   True
# F   True   True   True   True

# %% [markdown]
# STEPENOVANJE NAD DF-OM

# %%
np.power(data[['x_val', 'y_val']],2)
# Out:
#    x_val  y_val
# A    1.0    9.0
# B    4.0   16.0
# C   36.0   16.0
# D   25.0   49.0
# F    NaN    NaN

# %%
def f(x):
  return x+5

# %%
nesto=f(1)
print(f(1))
# Out:
# 6

# %%
f(data[['x_val', 'y_val']])
#u duhu funkcionalne paradigme
# Out:
#    x_val  y_val
# A    6.0    8.0
# B    7.0    9.0
# C   11.0    9.0
# D   10.0   12.0
# F    NaN    NaN

# %%
data[['x_val', 'y_val']].map(f)
#u duhu OO paradigme
# Out:
#    x_val  y_val
# A    6.0    8.0
# B    7.0    9.0
# C   11.0    9.0
# D   10.0   12.0
# F    NaN    NaN

# %%
data[['x_val', 'y_val']].map(lambda x:x+5)
#ovo je genijalno
# Out:
#    x_val  y_val
# A    6.0    8.0
# B    7.0    9.0
# C   11.0    9.0
# D   10.0   12.0
# F    NaN    NaN

# %%
data[['y_val']].map(lambda x:x+5)
#ovo je genijalno
# Out:
#    y_val
# A    8.0
# B    9.0
# C    9.0
# D   12.0
# F    NaN

# %%
data
# Out:
#    x_val  y_val color  nista
# A    1.0    3.0  blue    NaN
# B    2.0    4.0   red    NaN
# C    6.0    4.0  blue    NaN
# D    5.0    7.0  blue    NaN
# F    NaN    NaN   NaN    NaN

# %%
np.max(data.x_val)
# Out:
# 6.0

# %%
np.max(data[['x_val','y_val']], axis=1)
# Out:
# A    3.0
# B    4.0
# C    6.0
# D    7.0
# F    NaN
# dtype: float64

# %%
np.max(data[['x_val','y_val','nista']], axis=1)
#koji je max od svake vrste
# Out:
# A    3.0
# B    4.0
# C    6.0
# D    7.0
# F    NaN
# dtype: float64

# %%
np.max(data[['x_val','y_val','nista']])
# Out:
# 7.0

# %%
def f(linija):
   return np.sqrt(linija.x_val**2 + linija.y_val**2)
f(data)
# Out:
# A    3.162278
# B    4.472136
# C    7.211103
# D    8.602325
# F         NaN
# dtype: float64

# %%
data.apply(f, axis=1)
#elegantniji nacin
# Out:
# A    3.162278
# B    4.472136
# C    7.211103
# D    8.602325
# F         NaN
# dtype: float64

# %%
data['nista']=data.apply(lambda l:np.sqrt(l.x_val**2+l.y_val**2),axis=1)

# %%
data
# Out:
#    x_val  y_val color     nista
# A    1.0    3.0  blue  3.162278
# B    2.0    4.0   red  4.472136
# C    6.0    4.0  blue  7.211103
# D    5.0    7.0  blue  8.602325
# F    NaN    NaN   NaN       NaN

# %%
data[['x_val', 'y_val', 'nista']].max()
# Out:
# x_val    6.000000
# y_val    7.000000
# nista    8.602325
# dtype: float64

# %%
data['nista'].sum()
# Out:
# np.float64(23.447841433138564)

# %%
print(data['nista'].sum())
# Out:
# 23.447841433138564

# %%
d1=data[['y_val']].map(lambda x:x+5)

# %%
print(data[['x_val', 'y_val', 'nista']].mean(axis=1))
# Out:
# A    2.387426
# B    3.490712
# C    5.737034
# D    6.867442
# F         NaN
# dtype: float64

# %%
data
# Out:
#    x_val  y_val color     nista
# A    1.0    3.0  blue  3.162278
# B    2.0    4.0   red  4.472136
# C    6.0    4.0  blue  7.211103
# D    5.0    7.0  blue  8.602325
# F    NaN    NaN   NaN       NaN

# %%
data.dropna(axis=0, how='any', inplace=True)
#ovako moze bilo koja radnja da se sacuva

# %%
data
# Out:
#    x_val  y_val color     nista
# A    1.0    3.0  blue  3.162278
# B    2.0    4.0   red  4.472136
# C    6.0    4.0  blue  7.211103
# D    5.0    7.0  blue  8.602325

# %% [markdown]
# PLOTOVANJE DF-A

# %%
data.plot.scatter(x='x_val', y='y_val', c='color', s=50)
# Out:
# <Axes: xlabel='x_val', ylabel='y_val'>

# %% [markdown]
# DRUGO PREDAVANJE

# %% [markdown]
# GRUPISANJE

# %%
data
# Out:
#   name  x_val  y_val
# 0    A      1      3
# 1    B      2      4
# 2    C      6      4
# 3    D      5      7

# %%
data.groupby('y_val')

# %%
data.groupby('y_val').mean()

# %%
data=pd.DataFrame({

'x_value' : [1,2,6,5],
'y_value' : [3,4,4,7],
 'color' : ['red', 'blue', 'green', 'blue'],
}
)

# %%
data
# Out:
#    x_value  y_value  color
# 0        1        3    red
# 1        2        4   blue
# 2        6        4  green
# 3        5        7   blue

# %%
data.groupby('color').aggregate(['mean','median'])
# Out:
#       x_value        y_value
#          mean median    mean median
# color
# blue      3.5    3.5     5.5    5.5
# green     6.0    6.0     4.0    4.0
# red       1.0    1.0     3.0    3.0

# %%
tmp = data.groupby('color').aggregate(['mean','median'])

# %%
tmp
# Out:
#       x_value        y_value
#          mean median    mean median
# color
# blue      3.5    3.5     5.5    5.5
# green     6.0    6.0     4.0    4.0
# red       1.0    1.0     3.0    3.0

# %% [markdown]
# ovo su dvojke indeksa:

# %%
tmp.columns
# Out:
# MultiIndex([('x_value',   'mean'),
#             ('x_value', 'median'),
#             ('y_value',   'mean'),
#             ('y_value', 'median')],
#            )

# %% [markdown]
# OBICNO PYTHON GRUPISANJE:

# %%
data
# Out:
#    x_value  y_value  color
# 0        1        3    red
# 1        2        4   blue
# 2        6        4  green
# 3        5        7   blue

# %%
for color in ['red', 'blue', 'green']:
  print(color)
  for kolona in data.columns:
    if kolona != 'color':
      print("\t",kolona,data[data['color']==color][kolona].mean())
# Out:
# red
# 	 x_value 1.0
# 	 y_value 3.0
# blue
# 	 x_value 3.5
# 	 y_value 5.5
# green
# 	 x_value 6.0
# 	 y_value 4.0

# %%
data.groupby('color').count()
# Out:
#        x_value  y_value
# color
# blue         2        2
# green        1        1
# red          1        1

# %%
data['color'].value_counts()
#fino za frekvenciju pojavljivanja
# Out:
# color
# blue     2
# red      1
# green    1
# Name: count, dtype: int64

# %%
data['color'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
data['color'].value_counts().plot(kind='pie',autopct="%1.0f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# RAD SA CSV PODACIMA

# %%
from google.colab import files
fajl=files.upload()
# Out:
#      <input type="file" id="files-6f32e0d6-0245-4f62-ae73-3440986f1b13" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f32e0d6-0245-4f62-ae73-3440986f1b13">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# UCITAVANJE CSV FAJLA U DATAFRAME:

# %%
dt=pd.read_csv('preostala-mesta-skole.csv')

# %%
dt.head()
#ispise prvih 5 redova ako nemam argumente
# Out:
#          Општина                                              Школа  \
# 0            Ада                                Техничка школа, Ада
# 1  Александровац  Средња школа "Свети Трифун" са домом ученика, ...
# 2      Алексинац                   Алексиначка гимназија, Алексинац
# 3      Алексинац         Биотехнолошка школа "Шуматовац", Алексинац
# 4      Алексинац  Техничка школа "Прота Стеван Димитријевић", Ал...
#
#    Мин. бодова  Укупно места  Преостало места
# 0        39.37           150               78
# 1        42.77            90               48
# 2        63.19            90               29
# 3        40.76            60               25
# 4        50.16            30                1

# %%
dt.columns
# Out:
# Index(['Општина', 'Школа', 'Мин. бодова', 'Укупно места', 'Преостало места'], dtype='object')

# %%
dt['Школа'].head()
# Out:
# 0                                  Техничка школа, Ада
# 1    Средња школа "Свети Трифун" са домом ученика, ...
# 2                     Алексиначка гимназија, Алексинац
# 3           Биотехнолошка школа "Шуматовац", Алексинац
# 4    Техничка школа "Прота Стеван Димитријевић", Ал...
# Name: Школа, dtype: object

# %%
dt['Школа'][10:20]
#slice od 10. do 20. reda
# Out:
# 10                  Средња школа "Свети Ахилије", Ариље
# 11    Средња школа "Вук Караџић" са домом ученика, Б...
# 12                        Техничка школа , Бајина Башта
# 13                               Средња школа, Барајево
# 14                Средња школа "Никола Тесла", Баточина
# 15                             Пољопривредна школа, Бач
# 16               Гимназија "20. октобар", Бачка Паланка
# 17    Средња стручна школа "Др Радивој Увалић", Бачк...
# 18               Техничка школа "9. мај", Бачка Паланка
# 19    Гимназија и економска школа "Доситеј Обрадовић...
# Name: Школа, dtype: object

# %%
dt.sort_values('Мин. бодова', ascending=False)
# Out:
#                 Општина                                              Школа  \
# 93             Зрењанин                    Зрењанинска гимназија, Зрењанин
# 228                 Пећ  Економско-трговинска школа "Милева Вуковић", Г...
# 174           Мајданпек    Гимназија "Миле Арсенијевић Бандера", Мајданпек
# 56                Врање                  Гимназија "Бора Станковић", Врање
# 125  Косовска Митровица                      Гимназија, Косовска Митровица
# ..                  ...                                                ...
# 69              Вучитрн           Техничка школа "Никола Тесла" , Прилужје
# 244           Пријепоље                         Техничка школа , Пријепоље
# 90                Земун  Школа за ученике оштећеног вида "Вељко Рамадан...
# 206            Нови Сад  Школа за основно и средње образовање "Милан Пе...
# 263        Савски венац  Школа за оштећене слухом-наглуве "Стефан Дечан...
#
#      Мин. бодова  Укупно места  Преостало места
# ...

# %%
dt.sort_values('Укупно места', ascending=False)
# Out:
#           Општина                                              Школа  \
# 329         Чачак                                   Гимназија, Чачак
# 138      Крушевац                                Гимназија, Крушевац
# 299    Стари град              Трговачка школа, Београд (Стари Град)
# 335      Чукарица  Хемијско-прехрамбена технолошка школа, Београд...
# 158      Лесковац                                Гимназија, Лесковац
# ..            ...                                                ...
# 234     Пожаревац                      Политехничка школа, Пожаревац
# 61         Врачар               Техничка школа ГСП, Београд (Врачар)
# 206      Нови Сад  Школа за основно и средње образовање "Милан Пе...
# 90          Земун  Школа за ученике оштећеног вида "Вељко Рамадан...
# 263  Савски венац  Школа за оштећене слухом-наглуве "Стефан Дечан...
#
#      Мин. бодова  Укупно места  Преостало места
# 329        53.97           270               12
# ...

# %%
spd=dt.sort_values('Мин. бодова', ascending=False)
spd20 =spd[:20]
plt.barh(spd20['Школа'], spd20['Мин. бодова'])
# Out:
# <BarContainer object of 20 artists>

# %%
spd=dt.sort_values('Преостало места', ascending=True)
spd10 =spd[:10]
print(spd10['Школа'])
#plt.barh(spd10['Школа'], spd10['Преостало места'])
# Out:
# 4      Техничка школа "Прота Стеван Димитријевић", Ал...
# 12                         Техничка школа , Бајина Башта
# 237                              Техничка школа , Пожега
# 133                                   Гимназија, Краљево
# 339                             Шабачка гимназија, Шабац
# 18                Техничка школа "9. мај", Бачка Паланка
# 322               Техничка школа "Радоје Љубичић", Ужице
# 309             Техничка школа "Никола Тесла", Сурдулица
# 269                       Средња медицинска школа, Сента
# 247    Економско-трговинска школа из Приштине у Лапље...
# Name: Школа, dtype: object

# %%
pd=dt.sort_values('Преостало места', ascending=False)
print(pd["Школа"][:10])
# Out:
# 200    Пољопривредна школа са домом ученика "Футог", ...
# 213        Железничка техничка школа, Београд (Палилула)
# 335    Хемијско-прехрамбена технолошка школа, Београд...
# 310              Средња школа "Лукијан Мушицки", Темерин
# 131                     Средња стручна школа, Крагујевац
# 317                               Техничка школа , Тутин
# 54     Техничка школа за дизајн коже, Београд (Вождовац)
# 299                Трговачка школа, Београд (Стари Град)
# 303                         Политехничка школа, Суботица
# 85                 Грађевинска школа, Београд (Звездара)
# Name: Школа, dtype: object

# %%
plt.hist(dt['Преостало места'])
plt.grid()
#histogram

# %% [markdown]
# FILTRIRANJE TABELE

# %%
dt[dt['Општина'=='']]

# %%
dt[dt['Преостало места']>100]
# Out:
#                 Општина                                              Школа  \
# 131          Крагујевац                   Средња стручна школа, Крагујевац
# 200            Нови Сад  Пољопривредна школа са домом ученика "Футог", ...
# 213  Палилула (Београд)      Железничка техничка школа, Београд (Палилула)
# 310             Темерин            Средња школа "Лукијан Мушицки", Темерин
# 335            Чукарица  Хемијско-прехрамбена технолошка школа, Београд...
#
#      Мин. бодова  Укупно места  Преостало места
# 131        41.35           150              101
# 200        43.94           180              112
# 213        50.27           210              111
# 310        37.87           180              104
# 335        40.56           210              108

# %%
dt[dt['Преостало места']<=5].sort_values(['Преостало места'])
#isto to ako hocemo da sortiramo

# %%
d1=dt['Општина'].value_counts().head(5)

# %%
d1
# Out:
# Општина
# Нови Сад    10
# Лесковац     8
# Суботица     7
# Зрењанин     6
# Панчево      6
# Name: count, dtype: int64

# %%
d1.plot.bar()
plt.xlabel("Општина")
plt.ylabel("Count")
plt.title("Top 5 Општина by Frequency")
plt.show()

# %% [markdown]
# MEDIJANA:

# %%
mArea=dt['Мин. бодова'].mean()
mdArea=dt['Мин. бодова'].median()
plt.hist(dt['Мин. бодова'], 12, range=(0,120))
plt.grid()
plt.vlines(mArea,0,60,colors='orange')
plt.vlines(mdArea,0,60,colors='red')

# %%
plt.hist(dt['Мин. бодова'])
# Out:
# (array([  5.,  52., 120.,  45.,  63.,  27.,  15.,   7.,   3.,   3.]),
#  array([28.73 , 33.782, 38.834, 43.886, 48.938, 53.99 , 59.042, 64.094,
#         69.146, 74.198, 79.25 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# TITANIK OBRADA PODATAKA

# %%
from google.colab import files
fajl=files.upload()
# Out:
#      <input type="file" id="files-c31c6014-d2da-4fb3-ad8a-595823b33d56" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c31c6014-d2da-4fb3-ad8a-595823b33d56">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
